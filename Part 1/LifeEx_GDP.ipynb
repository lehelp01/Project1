# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv("Life_Expectancy_2004-2014.csv")
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2014  Developing              59.9              271
# 1  Afghanistan  2013  Developing              59.9              268
# 2  Afghanistan  2012  Developing              59.5              272
# 3  Afghanistan  2011  Developing              59.2              275
# 4  Afghanistan  2010  Developing              58.8              279
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             64     0.01               73.523582           62       492  ...
# 1             66     0.01               73.219243           64       430  ...
# 2             69     0.01               78.184215           67      2787  ...
# 3             71     0.01                7.097109           68      3013  ...
# 4             74     0.01               79.679367           66      1989  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0     58               8.18           62        0.1  612.696514    327582.0
# 1     62               8.13           64        0.1  631.744976  31700000.0
# 2     67               8.52           67        0.1  669.959000   3700000.0
# 3     68               7.87           68        0.1   63.537231   2980000.0
# 4     66               9.20           66        0.1  553.328940   2880000.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.5                 17.5
# 1                   17.7                 17.7
# 2                   17.9                 18.0
# 3                   18.2                 18.2
# 4                   18.4                 18.4
#
#    Income composition of resources  Schooling
# 0                            0.476       10.0
# 1                            0.470        9.9
# 2                            0.463        9.8
# 3                            0.454        9.5
# 4                            0.448        9.2
#
# [5 rows x 22 columns]

# %%
#plot scatter plot to show corelation between life expectancy and population
x = data.iloc[:,3]
y = data.iloc[:,-5]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.xlabel("Life Expectancy")
plt.ylabel("Population")
plt.title("Life Expectancy & Population Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = data.iloc[:,[3,17]]
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Life Expectancy & Population Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above images show that there is a weak negative correlation between life expectancy and population in the dataset. This means that when life expectancy increases, population tends to decrease, but in a weak or unreliable manner.

# %%
#plot scatter plot to show corelation between life expectancy and GDP
x = data.iloc[:,3]
y = data.iloc[:,-6]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.xlabel("Life Expectancy")
plt.ylabel("GDP")
plt.title("Life Expectancy & GDP Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = data.iloc[:,[3,16]]
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Life Expectancy & GDP Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above images show that there is a weak positive correlation between life expectancy and population in the dataset. This means that although both life expectancy and GDP tend to go up in response to one another, the relationship is not very strong.

# %%
#calculate GDP per capita
data["GDP_per_capita"] = data["GDP"] / data.iloc[:,-5]
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2014  Developing              59.9              271
# 1  Afghanistan  2013  Developing              59.9              268
# 2  Afghanistan  2012  Developing              59.5              272
# 3  Afghanistan  2011  Developing              59.2              275
# 4  Afghanistan  2010  Developing              58.8              279
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             64     0.01               73.523582           62       492  ...
# 1             66     0.01               73.219243           64       430  ...
# 2             69     0.01               78.184215           67      2787  ...
# 3             71     0.01                7.097109           68      3013  ...
# 4             74     0.01               79.679367           66      1989  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.18           62        0.1  612.696514    327582.0
# 1               8.13           64        0.1  631.744976  31700000.0
# 2               8.52           67        0.1  669.959000   3700000.0
# 3               7.87           68        0.1   63.537231   2980000.0
# 4               9.20           66        0.1  553.328940   2880000.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.5                 17.5
# 1                   17.7                 17.7
# 2                   17.9                 18.0
# 3                   18.2                 18.2
# 4                   18.4                 18.4
#
#    Income composition of resources  Schooling  GDP_per_capita
# 0                            0.476       10.0        0.001870
# 1                            0.470        9.9        0.000020
# 2                            0.463        9.8        0.000181
# 3                            0.454        9.5        0.000021
# 4                            0.448        9.2        0.000192
#
# [5 rows x 23 columns]

# %%
#plot scatter plot to show corelation between life expectancy and GDP
x = data.iloc[:,3]
y = data.iloc[:,-1]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.xlabel("Life Expectancy")
plt.ylabel("GDP Per Capita")
plt.title("Relationship between Life Expectancy and GDP per capita")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = data.iloc[:,[3,22]]
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Relationship between Life Expectancy and GDP per capita")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above images show that there is a weak positive correlation between life expectancy and GDP in the dataset. This means that although both life expectancy and GDP per capita tend to go up in response to one another, the relationship is not very strong.
